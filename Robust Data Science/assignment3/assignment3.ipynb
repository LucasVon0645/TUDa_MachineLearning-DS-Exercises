# %% [markdown]
# ## Voluntary Assignment 3 Programming Exercise – R-Peak Detector

# %% [markdown]
# ### Task 1: Downloading a Real ECG Measurement and Performing R-Peak Detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The R-Peak detector chosen was the "visgraphdetector", which uses visibility graphs (Taulant Koka, Michael Muma)

# %%
import matplotlib.pyplot as plt
import numpy as np
import kagglehub
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import kagglehub
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# Download latest version
path = kagglehub.dataset_download("khyeh0719/ptb-xl-dataset")

print("Path to dataset files:", path)

# %%
ecg = electrocardiogram()
fs = 360
beta = 0.55
gamma = 0.5
lowcut = 4
M = 2*fs
time = np.arange(0,len(ecg)/360,1/360)

vgd = VisGraphDetector(360)
R_peaks, weights, weighted_signal = vgd.visgraphdetect(ecg, beta=beta, gamma=gamma, lowcut=lowcut, M = M)

plt.plot(time,ecg)
plt.plot(time[R_peaks],ecg[R_peaks],'X')
